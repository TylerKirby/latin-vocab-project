# %%
import os
import itertools

# %%
root_path = "/Users/tyler/cltk_data/latin/text/latin_text_latin_library/"
texts_paths = list(os.walk(root_path))

# %%
author_dirs = [x[0] for x in texts_paths if "." not in x[0]][1:]

# %%
texts_paths
# Out:
# [('/Users/tyler/cltk_data/latin/text/latin_text_latin_library/',
#   ['ottofreising',
#    'bible',
#    'galileo',
#    'hyginus',
#    'dante',
#    'capellanus',
#    'prudentius',
#    'martial',
#    'bultelius',
#    'lactantius',
#    'cato',
#    'hugo',
#    'addison',
#    'quintilian',
#    'gregorytours',
#    'caesar',
#    'kepler',
#    'cassiodorus',
#    'suetonius',
#    'abelard',
#    'melanchthon',
#    'theodosius',
#    'bede',
#    'eutropius',
#    'alanus',
#    'columella',
#    'orosius',
#    'augustine',
#    'statius',
#    'commodianus',
#    'justin',
#    'erasmus',
#    'ovid',
#    'isidore',
#    'lucretius',
#    'martinbraga',
#    'xylander',
#    'apuleius',
#    'walter',
#    'claudian',
#    'aquinas',
#    'may',
#    'justinian',
#    'juvenal',
#    'horace',
#    'vergil',
#    'livy',
#    'arnobius',
#    'leothegreat',
#    'kempis',
#    'gellius',
#    'mirandola',
#    'sha',
#    'ambrose',
#    'alcuin',
#    'albertanus',
# ...

# %%
len(texts_paths)
# Out:
# 97
