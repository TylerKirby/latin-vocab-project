# %%
from vocab_utils import CorpusAnalytics

# %%
path_to_texts = "/Users/tyler/cltk_data/latin/text/latin_text_latin_library/"
sample_texts = ["caesar/gall1_sample.txt"]
sample_corpus = CorpusAnalytics(sample_texts, path_to_texts, "lat")

# %%
sample_corpus.analytics["caesar/gall1_sample"]["clean_text"]
# Out:
# 'gallia est omnis divisa in partes tres  quarum unam incolunt belgae  aliam aquitani  tertiam qui ipsorum  lingua celtae  nostra galli appellantur  hi omnes lingua  institutis  legibus inter se differunt   gallos ab aquitanis garumna flumen  a belgis matrona et sequana dividit  horum omnium fortissimi sunt belgae   propterea quod a cultu atque humanitate provinciae longissime absunt  minimeque ad eos mercatores saepe commeant  atque ea quae ad effeminandos animos pertinent important  proximique sunt germanis  qui trans rhenum incolunt  quibuscum  continenter bellum gerunt  qua de causa helvetii quoque reliquos gallos virtute praecedunt  quod fere cotidianis proeliis  cum germanis contendunt  cum aut suis finibus eos prohibent aut ipsi in eorum finibus bellum gerunt  eorum una  pars  quam  gallos obtinere dictum est  initium capit a flumine rhodano  continetur garumna flumine  oceano  finibus belgarum  attingit  etiam ab sequanis et helvetiis flumen rhenum  vergit ad septentriones  be
# ...

# %%
sample_corpus.analytics["caesar/gall1_sample"]["lemmata"]
# Out:
# [('gallia', 'gallia'),
#  ('est', 'sum'),
#  ('omnis', 'omnis'),
#  ('divisa', 'divido'),
#  ('in', 'in'),
#  ('partes', 'pars'),
#  ('tres', 'tres'),
#  ('quarum', 'qui'),
#  ('unam', 'unus'),
#  ('incolunt', 'incolo1'),
#  ('belgae', 'belgae'),
#  ('aliam', 'alius'),
#  ('aquitani', 'aquitani'),
#  ('tertiam', 'tertius'),
#  ('qui', 'qui'),
#  ('ipsorum', 'ipse'),
#  ('lingua', 'lingua'),
#  ('celtae', 'celtae'),
#  ('nostra', 'noster'),
#  ('galli', 'gallus'),
#  ('appellantur', 'appello'),
#  ('hi', 'hic'),
#  ('omnes', 'omnis'),
#  ('lingua', 'lingua'),
#  ('institutis', 'institus'),
#  ('legibus', 'lex'),
#  ('inter', 'inter'),
#  ('se', 'sui'),
#  ('differunt', 'differo'),
#  ('gallos', 'gallus'),
#  ('ab', 'ab'),
#  ('aquitanis', 'aquitanis'),
#  ('garumna', 'garumna'),
#  ('flumen', 'flumen'),
#  ('a', 'ab'),
#  ('belgis', 'belgae'),
#  ('matrona', 'matrona'),
#  ('et', 'et'),
#  ('sequana', 'sequana'),
#  ('dividit', 'divido'),
#  ('horum', 'hic'),
#  ('omnium', 'omnis'),
# ...

# %%
sample_corpus.analytics["caesar/gall1_sample"]["lemmata_frequencies"]

# %%
sample_corpus.analytics["caesar/gall1_sample"]["ner_filtered_tokens"]

# %%
sample_corpus.analytics["caesar/gall1_sample"]["filtered_lemmata_frequencies"]
